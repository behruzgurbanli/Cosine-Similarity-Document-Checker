# %% [markdown]
#  Considered some text documents are a set of news articles related to three different news.
#  We determine Document Similarity. How similar two or more documents are concerning each other in this document collection.

# %% [markdown]
# # File Uploads / Libraries

# %%
import numpy as np
import matplotlib as plt
import pandas as pd
import seaborn as sns
from sklearn import preprocessing
import math
import io
import sklearn
import zipfile

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
texts_zip_file = '/content/drive/MyDrive/Datasets/Cosine Similarity for Documents/texts.zip'

# %%
with zipfile.ZipFile(texts_zip_file, 'r') as zip_ref:
  file_names = zip_ref.namelist()
  docs = []
  for file_name in file_names:
    if file_name.endswith('.txt'):
      with zip_ref.open(file_name, 'r') as file:
        docs.append(file.read().decode('utf-8'))

# %% [markdown]
# # Data Cleaning
# *   Removal of stop words. (These are the most common words in any language (like articles, prepositions, pronouns, conjunctions, etc.) and do not add much information to the text.)
# *   Removal of numbers and special characters.
# *   Convert all the letters in the documents to lowercase letters.

# %%
import re

# %%
clean_docs = docs.copy()

# %%
with open('/content/drive/MyDrive/Datasets/Cosine Similarity for Documents/stop_words.txt', 'r', encoding='utf-8') as file:
  stop_words_list = set(file.read().split())

# %%
def clean_text(text, stop_words):
  text = re.sub(r'[\d.,!@#$%^&*:()"”“\-–=/]', ' ', text).lower()
  words = text.split()
  filtered_text = ' '.join(word for word in words if word not in stop_words)
  return filtered_text

# %%
for i in range(len(clean_docs)):
  clean_docs[i] = clean_text(clean_docs[i], stop_words_list)

# %%
print(clean_docs[0])
# Out:
# sabah misli premyer liqasında mövsümünə yekun vurulacaq millətin səsi az xəbər verir turun azersun arena keçiriləcək araz naxçıvan qarabağ oyunundan sonra qarabağ qızıl medallar çempionluq kuboku təqdim ediləcək qarabağ yaydığı açıqlamada bildirilib klub prezidenti tahir gözel ölkə xaricində təşkil olunan vacib tədbirə qatıldığı mükafatlandırmada iştirak edə bilməyəcək o klubun mətbuat xidmətinə açıqlamasında komandanı azarkeşləri növbəti uğurlu mövsüm münasibətilə təbrik edib möhtəşəm mövsümə şahid olduq azərbaycan xalqı dünya avropada mükəmməl qarabağ izlədi ardıcıl dəfə avrokubokların qrupunda mübarizə aparan komandamız pley offda portuqaliyanın tanınmış braqa klubunu məğlub etdi avropada kimə uduzmayan bayer seriyasını qırmağa yaxın oldu almaniya təmsilçisinin baş məşqçisi futbolçuları komandamızla qarşılaşmaların çətin keçdiyini dəfələrlə vurğuladılar uğurların ardınca qarabağ premyer liqada ardıcıl tarixində çempionluğunu qazandı sabah komandamıza növbəti qızıl medallar təqdim olunacaq vacib təxirəsalınmaz işlərimlə bağlı komandamızın mükafatlandırma mərasimində iştirak edə bilməyəcəyəm amma ürəyim komandamızın yanında olacaq dəfə qızıl medalları sona tur qalmış təmin etdik yeni rekord oldu hətta avropada dünyada erkən çempionluq tituluna yiyələnən komandalar az olub buna uğur asanlıqla əldə edilmədi komanda bizdən xal almağa çalışır qarabağ avropada tarix yazdıqca azərbaycan çempionatında komandanın bizə motivasiyası artır bizi sevindirir yerli klubların bizə rəqabət yaratmağa çalışması qarabağ ı avropaya yaxşı hazırlayır çempionatın səviyyəsinin qalxmasına təkan verir düşünməsin premyer liqadakı rəqiblərimiz zəifdir əksinə onlar güclüdürlər amma onların qarşısında güclü avropa təcrübəsinə malik qarabağ uğurlar bizim qarabağ yaratdığımız birlik ruhunun nəticəsidir klubun rəhbərliyindən baş məşqçisindən sıravi işçisinə hamının böyük mənəvi birlik rekord sayda çempionluq münasibətilə başda məşqçilər heyəti olmaqla futbolçularımı klubumuzda çalışan kəsi ürəyi qarabağ la döyünən azarkeşlərimizi təbrik edirəm tahir gözəl növbəti hədəflərə toxunub əldə olunan nəticələr qarabağ dünya avropa reytinqlərində yüksəlməsinə əsas verib komandamız beynəlxalq futbol tarixi statistikaları federasiyasının dünya reytinqində yerdədir on minlərlə klub siyahida yer almaq mübarizə aparır çempionluq kubokunu doğma azersun arena aldıqdan sonra bizi kubok uğrunda final qarşılaşması gözləyir həmin oyunda iştirak edəcəyəm görüşü səbirsizliklə həyəcanla gözləyirəm zirə güclü komandadır rəşad sadıqov mükəmməl heyət formalaşdırıb amma biz titul qazanmağa mövsümü qızıl dubl la tamamlanmağa çalışacağıq ardınca isə yeni mövsümə böyük motivasiya böyük ümid inamla hazırlaşacağıq titulumuzu növbəti dəfə qorumaq avropada yeni tarixlər yazmaq mübarizə aparacağıq i̇llərdir qarabağ adını avropada qürurla daşıyırıq artıq müzəffər ali baş komandanımızın rəhbərliyi azərbaycan əsgərinin böyük zəfəri sayəsində azad qarabağı təmsil edirik qarabağ adının klubun azərbaycan mənəvi cəhətdən necə önəm daşıdığını anlayırıq bilirik qarabağ futbol klubu missiyamız bitmir bundan sonra qarabağın adını avropada layiqincə təmsil etməliyik mənim əsas klubumuzun illik uğuru deyil davamlı nəticələrdir komandamıza inamım sonsuzdur qol az

# %% [markdown]
# # Cosine Similarity Application

# %%
tfidf = TfidfVectorizer()

# %%
response = tfidf.fit_transform(clean_docs)

# %%
tfidf.get_feature_names_out()
# Out:
# array(['_________________________________', '__cf',
#        '__google_lidar_radf_', ..., 'әn', 'әrzindә', 'әһali'],
#       dtype=object)

# %%
tfidf.vocabulary_
# Out:
# {'sabah': 87914,
#  'misli': 59294,
#  'premyer': 74606,
#  'liqasında': 55317,
#  'mövsümünə': 60679,
#  'yekun': 116867,
#  'vurulacaq': 110319,
#  'millətin': 58700,
#  'səsi': 98054,
#  'az': 7068,
#  'xəbər': 113037,
#  'verir': 109432,
#  'turun': 102466,
#  'azersun': 7333,
#  'arena': 4281,
#  'keçiriləcək': 49554,
#  'araz': 4110,
#  'naxçıvan': 66525,
#  'qarabağ': 77161,
#  'oyunundan': 71793,
#  'sonra': 92913,
#  'qızıl': 83244,
#  'medallar': 57670,
#  'çempionluq': 122596,
#  'kuboku': 52400,
#  'təqdim': 105171,
#  'ediləcək': 27848,
#  'yaydığı': 115654,
#  'açıqlamada': 8080,
#  'bildirilib': 12195,
#  'klub': 50700,
#  'prezidenti': 74667,
#  'tahir': 98571,
#  'gözel': 36322,
#  'ölkə': 125083,
#  'xaricində': 111885,
#  'təşkil': 106363,
#  'olunan': 70149,
#  'vacib': 108393,
#  'tədbirə': 103821,
#  'qatıldığı': 78274,
#  'mükafatlandırmada': 61373,
#  'iştirak': 47849,
#  'edə': 27973,
#  'bilməyəcək': 12604,
#  'klubun': 50722,
#  'mətbuat': 65479,
#  'xidmətinə': 112344,
#  'açıqlamasında': 8116,
#  'komandanı': 51029,
#  'azarkeşləri': 7257,
#  'növbəti': 68126,
#  'uğurlu': 108251,
#  'mövsüm': 60665,
#  'münasibətilə': 61575,
#  'təbrik': 103518,
#  'edib': 27680,
#  'möhtəşəm': 60510,
#  'mövsümə': 60680,
#  'şahid': 127467,
#  'olduq': 69739,
#  'azərbaycan': 7496,
#  'xalqı': 111493,
#  'dünya': 25186,
#  'avropada': 6127,
#  'mükəmməl': 61416,
#  'izlədi': 47164,
#  'ardıcıl': 4250,
#  'dəfə': 26223,
#  'avrokubokların': 6116,
#  'qrupunda': 81474,
#  'mübarizə': 60896,
#  'aparan': 3597,
#  'komandamız': 51000,
#  'pley': 73955,
#  'offda': 69421,
#  'portuqaliyanın': 74277,
#  'tanınmış': 99177,
#  'braqa': 14331,
#  'klubunu': 50725,
#  'məğlub': 65793,
#  'etdi': 29657,
#  'kimə': 50246,
#  'uduzmayan': 106940,
#  'bayer': 10496,
#  'seriyasını': 90661,
#  'qırmağa': 82993,
#  'yaxın': 115410,
#  'oldu': 69722,
#  'almaniya': 2029,
#  'təmsilçisinin': 104924,
#  'baş': 11115,
#  'məşqçisi': 65897,
#  'futbolçuları': 32665,
#  'komandamızla': 51003,
#  'qarşılaşmaların': 77984,
#  'çətin': 124749,
#  'keçdiyini': 49394,
#  'dəfələrlə': 26234,
#  'vurğuladılar': 110408,
#  'uğurların': 108239,
#  'ardınca': 4262,
#  'liqada': 55312,
#  'tarixində': 99742,
#  'çempionluğunu': 122601,
#  'qazandı': 78979,
#  'komandamıza': 51001,
#  'olunacaq': 70135,
#  'təxirəsalınmaz': 106106,
#  'işlərimlə': 47737,
#  'bağlı': 10913,
#  'komandamızın': 51005,
#  'mükafatlandırma': 61372,
#  'mərasimində': 64760,
#  'bilməyəcəyəm': 12627,
#  'amma': 2817,
#  'ürəyim': 126659,
#  'yanında': 114244,
#  'olacaq': 69548,
#  'medalları': 57674,
#  'sona': 92863,
#  'tur': 102359,
#  'qalmış': 76555,
#  'təmin': 104731,
#  'etdik': 29663,
#  'yeni': 117062,
#  'rekord': 85719,
#  'hətta': 42369,
#  'dünyada': 25191,
#  'erkən': 29338,
#  'tituluna': 101146,
#  'yiyələnən': 118085,
#  'komandalar': 50986,
#  'olub': 70107,
#  'buna': 14709,
#  'uğur': 108210,
#  'asanlıqla': 5083,
#  'əldə': 130751,
#  'edilmədi': 27778,
#  'komanda': 50981,
#  'bizdən': 13491,
#  'xal': 111405,
#  'almağa': 2106,
#  'çalışır': 121770,
#  'tarix': 99702,
#  'yazdıqca': 115930,
#  'çempionatında': 122590,
#  'komandanın': 51040,
#  'bizə': 13564,
#  'motivasiyası': 59839,
#  'artır': 4586,
#  'bizi': 13496,
#  'sevindirir': 90952,
#  'yerli': 117371,
#  'klubların': 50712,
#  'rəqabət': 87490,
#  'yaratmağa': 114840,
#  'çalışması': 121713,
#  'avropaya': 6157,
#  'yaxşı': 115542,
#  'hazırlayır': 39620,
#  'çempionatın': 122588,
#  'səviyyəsinin': 98348,
#  'qalxmasına': 76652,
#  'təkan': 104189,
#  'düşünməsin': 25872,
#  'liqadakı': 55313,
#  'rəqiblərimiz': 87528,
#  'zəifdir': 121017,
#  'əksinə': 130533,
#  'onlar': 70438,
#  'güclüdürlər': 36649,
#  'onların': 70456,
#  'qarşısında': 78059,
#  'güclü': 36647,
#  'avropa': 6126,
#  'təcrübəsinə': 103722,
#  'malik': 56556,
#  'uğurlar': 108219,
#  'bizim': 13499,
#  'yaratdığımız': 114786,
#  'birlik': 13059,
#  'ruhunun': 86812,
#  'nəticəsidir': 68934,
#  'rəhbərliyindən': 87310,
#  'məşqçisindən': 65898,
#  'sıravi': 96100,
#  'işçisinə': 47955,
#  'hamının': 39014,
#  'böyük': 15452,
#  'mənəvi': 64524,
#  'sayda': 89827,
#  'başda': 11142,
#  'məşqçilər': 65892,
#  'heyəti': 40228,
#  'olmaqla': 69943,
#  'futbolçularımı': 32666,
#  'klubumuzda': 50720,
#  'çalışan': 121645,
#  'kəsi': 54078,
#  'ürəyi': 126657,
#  'la': 54333,
#  'döyünən': 24910,
#  'azarkeşlərimizi': 7258,
#  'edirəm': 27944,
#  'gözəl': 36573,
#  'hədəflərə': 41543,
#  'toxunub': 101877,
#  'nəticələr': 68904,
#  'reytinqlərində': 86139,
#  'yüksəlməsinə': 119384,
#  'əsas': 132014,
#  'verib': 109282,
#  'beynəlxalq': 11969,
#  'futbol': 32642,
#  'tarixi': 99709,
#  'statistikaları': 93814,
#  'federasiyasının': 31381,
#  'reytinqində': 86128,
#  'yerdədir': 117255,
#  'on': 70386,
#  'minlərlə': 58995,
#  'siyahida': 92356,
#  'yer': 117239,
#  'almaq': 2052,
#  'aparır': 3801,
#  'kubokunu': 52403,
#  'doğma': 23670,
#  'aldıqdan': 1803,
#  'kubok': 52397,
#  'uğrunda': 108197,
#  'final': 31806,
#  'qarşılaşması': 77989,
#  'gözləyir': 36488,
#  'həmin': 41730,
#  'oyunda': 71764,
#  'edəcəyəm': 28020,
#  'görüşü': 35623,
#  'səbirsizliklə': 96411,
#  'həyəcanla': 42529,
#  'gözləyirəm': 36507,
#  'zirə': 120432,
#  'komandadır': 50985,
#  'rəşad': 87826,
#  'sadıqov': 88105,
#  'heyət': 40224,
#  'formalaşdırıb': 32182,
#  'biz': 13481,
#  'titul': 101136,
#  'qazanmağa': 79067,
#  'mövsümü': 60674,
#  'dubl': 24025,
#  'tamamlanmağa': 98839,
#  'çalışacağıq': 121643,
#  'isə': 46602,
#  'motivasiya': 59836,
#  'ümid': 126342,
#  'inamla': 44248,
#  'hazırlaşacağıq': 39632,
#  'titulumuzu': 101145,
#  'qorumaq': 80364,
#  'tarixlər': 99765,
#  'yazmaq': 116001,
#  'aparacağıq': 3593,
#  'llərdir': 55476,
#  'adını': 936,
#  'qürurla': 82658,
#  'daşıyırıq': 20876,
#  'artıq': 4578,
#  'müzəffər': 62578,
#  'ali': 1858,
#  'komandanımızın': 51038,
#  'rəhbərliyi': 87301,
#  'əsgərinin': 132182,
#  'zəfəri': 120906,
#  'sayəsində': 90049,
#  'azad': 7073,
#  'qarabağı': 77215,
#  'təmsil': 104895,
#  'edirik': 27907,
#  'adının': 938,
#  'cəhətdən': 18566,
#  'necə': 66820,
#  'önəm': 125525,
#  'daşıdığını': 20740,
#  'anlayırıq': 3301,
#  'bilirik': 12415,
#  'klubu': 50719,
#  'missiyamız': 59348,
#  'bitmir': 13413,
#  'bundan': 14720,
#  'qarabağın': 77230,
#  'layiqincə': 54716,
#  'etməliyik': 30163,
#  'mənim': 64244,
#  'klubumuzun': 50721,
#  'illik': 43627,
#  'uğuru': 108284,
#  'deyil': 21614,
#  'davamlı': 19974,
#  'nəticələrdir': 68906,
#  'inamım': 44267,
#  'sonsuzdur': 92955,
#  'qol': 80060,
#  'məlum': 63828,
#  'həqiqətdir': 41979,
#  'son': 92862,
#  'il': 43467,
#  'ərzində': 131930,
#  'siyasi': 92398,
#  'hərbi': 42035,
#  'gedişləri': 33648,
#  'regionda': 85584,
#  'reallıq': 85423,
#  'yaratdı': 114772,
#  'faktdır': 31014,
#  'günlük': 37339,
#  'müharibə': 61201,
#  'azərbaycanın': 7635,
#  'tam': 98790,
#  'qələbəsi': 83867,
#  'nəticələndi': 68875,
#  'dövr': 24779,
#  'kənd': 53868,
#  'şəhər': 129267,
#  'qəsəbə': 84257,
#  'çoxsaylı': 123314,
#  'strateji': 94073,
#  'yüksəkliklər': 119292,
#  'olundu': 70173,
#  'incisi': 44489,
#  'şuşa': 128642,
#  'şəhərini': 129317,
#  'gündə': 37265,
#  'kəndi': 53876,
#  'yüksəkliyi': 119304,
#  'etməklə': 30146,
#  'ermənistanı': 29504,
#  'diz': 23000,
#  'çökdürdü': 123416,
#  'kapitulyasiyaya': 48781,
#  'məcbur': 63034,
#  'məsələnin': 65442,
#  'həllində': 41662,
#  'mühüm': 61312,
#  'addım': 590,
#  'ötən': 125720,
#  'sentyabrın': 90488,
#  'keçirilən': 49567,
#  'antiterror': 3499,
#  'tədbirləri': 103800,
#  'ordumuz': 70697,
#  'qarabağda': 77169,
#  'lokal': 55564,
#  'nəticəsində': 68940,
#  'erməni': 29365,
#  'birləşmələrini': 13231,
#  'cəmi': 18660,
#  'saat': 87879,
#  'tərəf': 105516,
#  'ağ': 8215,
#  'bayraq': 10569,
#  'qaldıraraq': 76233,
#  'təslim': 105933,
#  'xatırladaq': 112052,
#  'apardığı': 3639,
#  'xarakterli': 111858,
#  'idi': 43103,
#  'ordumuzun': 70703,
#  'qarşısına': 78057,
#  'mülki': 61447,
#  'obyektlərə': 69326,
#  'insanlara': 44883,
#  'zərər': 121422,
#  'yetirilməməsi': 117648,
#  'vəzifəsi': 111172,
#  'qoyulmuşdu': 81069,
#  'relyefi': 85758,
#  'dağlıq': 20456,
#  'olduğundan': 69778,
#  'qeyri': 79599,
#  'qanuni': 76906,
#  'silahlıları': 91728,
#  'uzun': 108013,
#  'müddət': 61079,
#  'yüksəkliklərdə': 119294,
#  'möhkəmləndiyindən': 60440,
#  'tədbirlərinin': 103815,
#  'aparılması': 3774,
#  'asan': 5054,
#  'məsələ': 65400,
#  'deyildi': 21617,
#  'verilən': 109418,
#  'tapşırığa': 99625,
#  'əsasən': 132148,
#  'legitim': 54887,
#  'hədəfləri': 41526,
#  'zərərsizləşdirdi': 121440,
#  'humanistliyə': 40797,
#  'aparılan': 3744,
#  'ən': 131537,
#  'nümunəvi': 68369,
#  'tədbiri': 103775,
#  'tarixə': 99821,
#  'düşdü': 25517,
#  'yüksək': 119279,
#  'dəqiqliklə': 26459,
#  'aparılmasına': 3776,
#  'peşəkarlığı': 73404,
#  'müasir': 60749,
#  'silahları': 91718,
#  'idarə': 42858,
#  'bacarığı': 9226,
#  'nail': 66037,
#  'ərazilərində': 131746,
#  'suverenlik': 94697,
#  'bərpa': 16380,
#  'edildi': 27709,
#  'əhalisinin': 130261,
#  'ölkəmizin': 125152,
#  'qanunvericiliyinin': 76975,
#  'tələblərinə': 104571,
#  'uyğun': 107680,
#  'yaşaya': 116611,
#  'biləcəyini': 12709,
#  'bəyan': 16593,
#  'ermənistan': 29479,
#  'hakimiyyəti': 38788,
#  'tamam': 98799,
#  'fərqli': 33217,
#  'planlar': 73752,
#  'qurdu': 81975,
#  'barədə': 9953,
#  'danışmazdan': 19670,
#  'öncə': 125440,
#  'qeyd': 79556,
#  'edək': 28021,
#  'tərəfi': 105605,
#  'qarabağdan': 77179,
#  'əhali': 130246,
#  'nin': 67256,
#  'köçündə': 53132,
#  'maraqlı': 57047,
#  'olmayıb': 70005,
#  'istəyi': 46500,
#  'böl': 15154,
#  'gədə': 37630,
#  'yaşayan': 116636,
#  'əhalinin': 130256,
#  're': 85248,
#  'inteqrasiyasına': 45101,
#  'olmaq': 69932,
#  'onları': 70455,
#  'təxminən': 106119,
#  'ildə': 43520,
#  'ermənista': 29477,
#  'nın': 68429,
#  'qanunsuz': 76940,
#  'separatçı': 90532,
#  'xunta': 112825,
#  'rejiminin': 85661,
#  'girovluğundan': 34611,
#  'qurtara': 82049,
#  'raq': 84838,
#  'ölkənin': 125166,
#  'sosial': 93136,
#  'iqtisadi': 45419,
#  'icti': 42809,
#  'mai': 56440,
#  'həyatına': 42508,
#  'qovuşdurmaq': 80747,
#  'şğal': 128979,
#  'bitdikdən': 13323,
#  'azər': 7473,
#  'baycan': 10478,
#  'özünün': 126182,
#  'sakinləri': 88413,
#  'təmas': 104698,
#  'qurmağa': 82031,
#  'hazır': 39491,
#  'olduğu': 69764,
#  'nu': 67904,
#  'bildirib': 12186,
#  'milli': 58621,
#  'məclisin': 63085,
#  'sabiq': 87942,
#  'deputatı': 21419,
#  'ramin': 84784,
#  'məmmədov': 63981,
#  'sakinlərlə': 88426,
#  'lar': 54541,
#  'üzrə': 126988,
#  'məsul': 65340,
#  'şəxs': 129771,
#  'müəyyən': 62839,
#  'martın': 57220,
#  'xocalıda': 112504,
#  'rusiya': 86889,
#  'sülhməramlı': 95426,
#  'larının': 54564,
#  'vasitəçiliyi': 108925,
#  'qə': 83399,
#  'rargahında': 84854,
#  'ilkin': 43611,
#  'təmaslar': 104705,
#  'aparılıb': 3793,
#  'təəssüf': 106667,
#  'təmaslardan': 104708,
#  'sakinlərin': 88419,
#  'nümayəndələri': 68296,
#  'arzuolunmaz': 4990,
#  'açıqlamalarının': 8101,
#  'şahidi': 127471,
#  'eyni': 30599,
#  'zamanda': 119995,
#  'mar': 56943,
#  'tın': 103373,
#  'tərəfindən': 105625,
#  'xankəndi': 111638,
#  'xəlfəli': 113129,
#  'turşsu': 102473,
#  'torpaq': 101629,
#  'yolunda': 118298,
#  'təxribat': 106123,
#  'törədildi': 102930,
#  'sakinlər': 88408,
#  'lə': 55869,
#  'təmaslara': 104706,
#  'mane': 56787,
#  'olmağa': 70023,
#  'he': 39738,
#  'sablanmışdı': 88013,
#  'təmasları': 104710,
#  'davam': 19965,
#  'etdirməkdə': 29793,
#  'qərarlı': 84076,
#  'onlara': 70439,
#  'ikinci': 43391,
#  'dəvət': 27137,
#  'göndərildi': 35001,
#  'imtina': 44007,
#  'etdilər': 29681,
#  'nəhayət': 68585,
#  'ermənilərin': 29396,
#  'özlərinin': 126081,
#  'təxribatları': 106137,
#  'sentyabr': 90479,
#  'ha': 38598,
#  'disələrinin': 22863,
#  'verməsini': 109592,
#  'şərtlən': 129672,
#  'dirdi': 22588,
#  'əməliyyatlardan': 131467,
#  'qon': 80115,
#  'darma': 19820,
#  'rejimin': 85655,
#  'keçmiş': 49743,
#  'indiki': 44568,
#  'qlavar': 79921,
#  'ları': 54553,
#  'istisna': 46281,
#  'həbs': 41340,
#  'bunlar': 14737,
#  'fonunda': 32085,
#  'məkrli': 63687,
#  'planların': 73771,
#  'icrasına': 42793,
#  'başladı': 11170,
#  'qərbdəki': 84113,
#  'havadarları': 39356,
#  'azərbay': 7483,
#  'can': 17022,
#  'ordusunun': 70721,
#  'dövlət': 24644,
#  'suveren': 94692,
#  'liyini': 55418,
#  'bərqərar': 16414,
#  'məqsədilə': 64656,
#  'hüquqa': 41143,
#  'keçirmək': 49632,
#  'məcburiyyətində': 63049,
#  'qaldı': 76198,
#  'ğı': 127320,
#  'tədbirlərindən': 103812,
#  'könüllü': 52858,
#  'şəkildə': 129380,
#  'ermənistana': 29481,
#  'getməsini': 34260,
#  'ölkəmizə': 125157,
#  'təzyiqin': 106303,
#  'elementinə': 28615,
#  'çevrməyə': 122824,
#  'çalışdılar': 121667,
#  'verənləri': 109744,
#  'olmadan': 69847,
#  'etnik': 30319,
#  'təmizləmə': 104807,
#  'məcburi': 63042,
#  'köçürülmə': 53181,
#  'sair': 88377,
#  'ad': 466,
#  'larla': 54549,
#  'qələmə': 83906,
#  'verdilər': 109224,
#  'istəklərinə': 46357,
#  'çata': 121941,
#  'bilımədilər': 12678,
#  'məqsədi': 64654,
#  'mənfi': 64203,
#  'obrazının': 69290,
#  'yaradılmasına': 114468,
#  'lobbisi': 55506,
#  'va': 108381,
#  'başında': 11569,
#  'duran': 24100,
#  'fransa': 32506,
#  'azərbaycanı': 7624,
#  'izolyasiya': 47277,
#  'niyyəti': 67355,
#  'güdürdülər': 36847,
#  'müstəmləkəsinə': 62085,
#  'çevirmək': 122668,
#  'revanşist': 86053,
#  'qüvvələrə': 82787,
#  'dəstək': 26916,
#  'verməyə': 109615,
#  'təcrid': 103660,
#  'etməyə': 30271,
#  'cəhd': 18522,
#  'göstərməyə': 36001,
#  'ermənistanın': 29507,
#  'silahlandırılması': 91685,
#  'təsisatlarında': 105908,
#  'qərəzli': 84196,
#  'qətnamələrin': 84382,
#  'qəbul': 83464,
#  'etdirilməsi': 29729,
#  'müxtəlif': 62500,
#  'qarayaxma': 77407,
#  'kampaniyalarının': 48608,
#  'işlərinə': 47748,
#  'başlanıldı': 11316,
#  'sanksiyaların': 88989,
#  'tətbiqi': 106057,
#  'məsələsi': 65450,
#  'gündəmə': 37324,
#  'gətirildi': 38300,
#  'cəhdləri': 18543,
#  'iflasa': 43259,
#  'uğradı': 108147,
#  'ndi': 66787,
#  'əks': 130511,
#  'mənzərə': 64479,
#  'müşahidə': 62600,
#  'olunur': 70322,
#  'ilin': 43583,
#  'fevralında': 31506,
#  'dövlətin': 24678,
#  'nümayəndələrinin': 68305,
#  'rəhbərinin': 87284,
#  'münhen': 61648,
#  'təhlükəsizlik': 104047,
#  'konfransında': 51450,
#  'azərbaycana': 7498,
#  'liderinə': 55140,
#  'diqqət': 22536,
#  'göstərildi': 35834,
#  'xüsusən': 112986,
#  'prezident': 74661,
#  'lham': 55054,
#  'əliyevin': 130960,
#  'təkcə': 104198,
#  'konfransındakı': 51451,
#  'görüşləri': 35565,
#  'apreldə': 3844,
#  'almaniyaya': 2043,
#  'səfəri': 96767,
#  'göstərir': 35890,
#  'olunmadı': 70196,
#  'mövqeyini': 60653,
#  'möhkəmləndirdi': 60386,
#  'azərbaycanla': 7540,
#  'digər': 21969,
#  'sahələrdə': 88320,
#  'əməkdaşlığa': 131388,
#  'atan': 5457,
#  'ölkələrin': 125125,
#  'sayı': 89948,
#  'artdı': 4461,
#  'ticarət': 100758,
#  'tərəfdaşları': 105555,
#  'ilk': 43606,
#  'yerlərdə': 117384,
#  'dayanan': 20194,
#  'avropanın': 6144,
#  'inkişaf': 44744,
#  'etmiş': 30089,
#  'dövlətlərindən': 24718,
#  'taliya': 98758,
#  'əlaqələrimiz': 130674,
#  'yüksələn': 119407,
#  'xətlə': 113407,
#  'edir': 27889,
#  'enerji': 29129,
#  'təhlükəsizliyinin': 104067,
#  'olunmasında': 70251,
#  'əhəmiyyətli': 130390,
#  'rola': 86493,
#  'ölkədir': 125094,
#  'ttifaqına': 102244,
#  'üzv': 126996,
#  'dövlətlə': 24697,
#  'tərəfdaşlıq': 105572,
#  'sənədlər': 97414,
#  'imzalanıb': 44160,
#  'geosiyasi': 33952,
#  'mahiyyəti': 56371,
#  'coğrafi': 17967,
#  'mövqeyi': 60636,
#  'imkanları': 43857,
#  'təbii': 103426,
#  'sərvətləri': 97996,
#  'dayanıqlı': 20340,
#  'inkişafa': 44745,
#  'meyilli': 58337,
#  'olması': 69963,
#  'dövlətləri': 24708,
#  'qarşılıqlı': 78020,
#  'faydalı': 31273,
#  'açıq': 8062,
#  'ciddi': 17549,
#  'qurumlarının': 82354,
#  'nəzərindədir': 69095,
#  'vropa': 110195,
#  'abş': 340,
#  'rəsmiləri': 87615,
#  'cop': 17922,
#  'azərbaycanda': 7511,
#  'keçirilməsini': 49538,
#  'dəstəkləyir': 27029,
#  'qlobal': 79933,
#  'tədbirin': 103781,
#  'keçirilməsi': 49534,
#  'köməklərini': 52806,
#  'təklif': 104233,
#  'edirlər': 27918,
#  'dünyanın': 25239,
#  'ölkələri': 125115,
#  'cümlədən': 18219,
#  'çin': 122941,
#  'yaponiya': 114281,
#  'afrika': 1026,
#  'başqaları': 11454,
#  'münasibətlərimiz': 61613,
#  'intensiv': 45052,
#  'fransanın': 32517,
#  'imicini': 43822,
#  'formalaşdırmaq': 32166,
#  'niyyətinin': 67373,
#  'iflasından': 43266,
#  'nahid': 66026,
#  'salayev': 88571,
#  'bakı': 9398,
#  'trend': 102109,
#  'xalqının': 111523,
#  'qarşılaşdığı': 77976,
#  'sınaqlardan': 95960,
#  'ulu': 107048,
#  'öndər': 125462,
#  'heydər': 40073,
#  'hakimiyyətdən': 38785,
#  'getməsindən': 34259,
#  'verən': 109730,
#  'faciələr': 30927,
#  'böhranlar': 15119,
#  'oktyabrında': 69539,
#  'əliyev': 130933,
#  'sovet': 93194,
#  'ttifaqı': 102241,
#  'kommunist': 51228,
#  'partiyası': 72518,
#  'mərkəzi': 64913,
#  'komitəsi': 51183,
#  'bürosunun': 15709,
#  'katib': 49093,
#  'mixail': 59420,
#  'qorbaçovun': 80321,
#  'siyasətinə': 92473,
#  'etiraz': 30020,
#  'edərək': 28077,
#  'istefa': 45914,
#  'verdi': 109211,
#  'istefasından': 45925,
#  'qısa': 83126,
#  'millətçiləri': 58736,
#  'tərkibindən': 105391,
#  'çıxarılıb': 123907,
#  'verilməsi': 109382,
#  'tələbi': 104542,
#  'çıxış': 124094,
#  'əgər': 130242,
#  'hakimiyyətdə': 38780,
#  'olsaydı': 70094,
#  'cür': 18257,
#  'cəhdlərə': 18554,
#  'cürət': 18268,
#  'etməzdilər': 30309,
#  'müstəqilliyin': 62149,
#  'illəri': 43679,
#  'axc': 6310,
#  'müsavat': 62001,
#  'qtidarıazərbaycanın': 81495,
#  'müstəqilliyinin': 62153,
#  'illərində': 43690,
#  'iqtidarının': 45416,
#  'səriştəsiz': 97838,
#  'idarəetməsi': 42875,
#  'ölkədə': 125096,
#  'problemlərə': 74937,
#  'səbəb': 96434,
#  'idarəçiliyi': 42913,
#  'sistemi': 92224,
#  'silahlı': 91725,
#  'dəstələr': 27071,
#  'bölgələrində': 15201,
#  'separatçılıq': 90547,
#  'meyllərini': 58390,
#  'gücləndirirdi': 36697,
#  'vəziyyət': 111197,
#  'ölkəni': 125165,
#  'vətəndaş': 110962,
#  'müharibəsi': 61237,
#  'üz': 126862,
#  'üzə': 127145,
#  'qoymuşdu': 80990,
#  'cütlüyü': 18288,
#  'yalnız': 113775,
#  'qalmağı': 76533,
#  'düşünərək': 25957,
#  'xalqın': 111517,
#  'rifahını': 86227,
#  'gözardı': 36315,
#  'əmlakını': 131296,
#  'talan': 98644,
#  'acınacaqlı': 438,
#  'duruma': 24208,
#  'saldı': 88579,
#  'xilaskarlıq': 112405,
#  'missiyası': 59356,
#  'iyununda': 47105,
#  'tənəzzüldən': 105099,
#  'xilas': 112393,
#  'biləcək': 12682,
#  'yeganə': 116840,
#  'lider': 55119,
#  'əliyevi': 130959,
#  'gördü': 35110,
#  'təkidli': 104214,
#  'bakıya': 9429,
#  'qayıdan': 78725,
#  'ictimai': 42812,
#  'pərakəndəliyin': 75681,
#  'anarxiyanın': 2975,
#  'məngənəsindən': 64232,
#  'qurtardı': 82067,
#  'liderliyi': 55147,
#  'altında': 2335,
#  'asayiş': 5092,
#  'qayda': 78414,
#  'qanun': 76885,
#  'nizami': 67405,
#  'ordu': 70667,
#  'yaradıldı': 114447,
#  'dirçəlişin': 22727,
#  'təməlləri': 104953,
#  'qoyuldu': 81035,
#  'qurtuluş': 82144,
#  'günü': 37395,
#  'yun': 118739,
#  'respublikası': 85952,
#  'sovetinin': 93205,
#  'sədri': 96600,
#  'seçildi': 91254,
#  'dərin': 26622,
#  'böhrandan': 15116,
#  'gün': 37151,
#  'müstəqillik': 62125,
#  'dönüş': 24536,
#  'nöqtəsi': 68090,
#  'məclis': 63078,
#  'elan': 28518,
#  'dinamik': 22251,
#  'edən': 28024,
#  'miqyasda': 59093,
#  'nüfuzu': 68212,
#  'artan': 4451,
#  'dövlətə': 24777,
#  'çevrilib': 122721,
#  'vətən': 110958,
#  'müharibəsində': 61242,
#  'qazanılan': 79103,
#  'zəfər': 120900,
#  'kursun': 52530,
#  'məntiqi': 64370,
#  'iyun': 47095,
#  'adı': 903,
#  'yaddaşlarda': 113613,
#  'qalacaq': 76082,
#  'missiyasını': 59362,
#  'xalqımızın': 111515,
#  'ətrafında': 132555,
#  'birləşməsini': 13242,
#  'simvolizə': 91965,
#  'əziz': 133029,
#  'xatirəsini': 112026,
#  'həmişə': 41736,
#  'uca': 106728,
#  'tutacaq': 102491,
#  'irsini': 45587,
#  'gələcək': 37948,
#  'nəsillərə': 68790,
#  'ötürməyə': 125670,
#  'edəcək': 27976,
#  'verdiyimiz': 109238,
#  'belarus': 11676,
#  'aleksandr': 1827,
#  'lukaşenko': 55660,
#  'şuşaya': 128704,
#  'füzuliyə': 32772,
#  'səfər': 96749,
#  'ediblər': 27686,
#  'bakıvaxtı': 9423,
#  'mediasına': 57714,
#  'istinadən': 46105,
#  'lukaşenkonun': 55664,
#  'qonaq': 80116,
#  'edildiyi': 27721,
#  'menyü': 58001,
#  'açıqlanıb': 8162,
#  'mətbəxindən': 65508,
#  'təamlar': 103405,
#  'kabab': 48324,
#  'plov': 73963,
#  'şirniyyatlar': 128315,
#  'sac': 88019,
#  'yeməyi': 117048,
#  'olunub': 70306,
#  'dövlətlərinin': 24722,
#  'mərkəzindədir': 64927,
#  'başçısı': 11532,
#  'hamını': 39013,
#  'başa': 11117,
#  'təcavüzkar': 103603,
#  'siyasət': 92432,
#  'həyata': 42465,
#  'keçirirlər': 49595,
#  'şğaldan': 128984,
#  'torpaqlarının': 101682,
#  'bərpası': 16398,
#  'dünənə': 25294,
#  'qaçqın': 79390,
#  'köçkün': 53060,
#  'insanların': 44902,
#  'dədə': 26173,
#  'baba': 9014,
#  'yurdlarına': 118809,
#  'qayıdışı': 78785,
#  'təcrübədir': 103684,
#  'mayın': 57503,
#  'ağdam': 8418,
#  'xocalıya': 112533,
#  'evi': 30420,
#  'diqqətlə': 22563,
#  'izləməsi': 47190,
#  'ev': 30394,
#  'sahibləri': 88254,
#  'analoqu': 2922,
#  'olmayan': 69990,
#  'hadisədir': 38691,
#  'xalq': 111444,
#  'torpaqları': 101657,
#  'düşməndən': 25600,
#  'torpaqlarımızı': 101668,
#  'cənnətə': 18818,
#  'çevirməkdir': 122669,
#  'torpağa': 101700,
#  'məhəbbətin': 63534,
#  'olduğunun': 69785,
#  'başçsının': 11505,
#  'günlərini': 37373,
#  'rayonlarında': 85012,
#  'birgə': 12939,
#  'keçirməsi': 49655,
#  'nadir': 65993,
#  'hadisələrdən': 38702,
#  'biridir': 12964,
#  'qarabağa': 77163,
#  'gedən': 33682,
#  'xarici': 111880,
#  'qonaqlar': 80122,
#  ...}

# %% [markdown]
# **Cosine Similarity Result**

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_similarities = cosine_similarity(response)

# %%
cosine_similarities
# Out:
# array([[1.        , 0.03988966, 0.02103145, ..., 0.01412431, 0.00987229,
#         0.02684606],
#        [0.03988966, 1.        , 0.07378404, ..., 0.04616042, 0.01863348,
#         0.03646492],
#        [0.02103145, 0.07378404, 1.        , ..., 0.01712214, 0.02078744,
#         0.03549032],
#        ...,
#        [0.01412431, 0.04616042, 0.01712214, ..., 1.        , 0.01112066,
#         0.01430345],
#        [0.00987229, 0.01863348, 0.02078744, ..., 0.01112066, 1.        ,
#         0.0285698 ],
#        [0.02684606, 0.03646492, 0.03549032, ..., 0.01430345, 0.0285698 ,
#         1.        ]])

# %%
num_docs = len(clean_docs)
found_similar_pair = False
for i in range(num_docs):
    for j in range(i + 1, num_docs):
        similarity = cosine_similarities[i, j]
        if round(similarity, 2) == 0.95:
            print(f"Documents {i} and {j} are similar with similarity score: {similarity:.2f}")
            found_similar_pair = True
            break
    if found_similar_pair:
        break
# Out:
# Documents 0 and 12232 are similar with similarity score: 0.95

# %%
print(clean_docs[i])
print(clean_docs[j])
# Out:
# sabah misli premyer liqasında mövsümünə yekun vurulacaq millətin səsi az xəbər verir turun azersun arena keçiriləcək araz naxçıvan qarabağ oyunundan sonra qarabağ qızıl medallar çempionluq kuboku təqdim ediləcək qarabağ yaydığı açıqlamada bildirilib klub prezidenti tahir gözel ölkə xaricində təşkil olunan vacib tədbirə qatıldığı mükafatlandırmada iştirak edə bilməyəcək o klubun mətbuat xidmətinə açıqlamasında komandanı azarkeşləri növbəti uğurlu mövsüm münasibətilə təbrik edib möhtəşəm mövsümə şahid olduq azərbaycan xalqı dünya avropada mükəmməl qarabağ izlədi ardıcıl dəfə avrokubokların qrupunda mübarizə aparan komandamız pley offda portuqaliyanın tanınmış braqa klubunu məğlub etdi avropada kimə uduzmayan bayer seriyasını qırmağa yaxın oldu almaniya təmsilçisinin baş məşqçisi futbolçuları komandamızla qarşılaşmaların çətin keçdiyini dəfələrlə vurğuladılar uğurların ardınca qarabağ premyer liqada ardıcıl tarixində çempionluğunu qazandı sabah komandamıza növbəti qızıl medallar təqdim olunacaq vacib təxirəsalınmaz işlərimlə bağlı komandamızın mükafatlandırma mərasimində iştirak edə bilməyəcəyəm amma ürəyim komandamızın yanında olacaq dəfə qızıl medalları sona tur qalmış təmin etdik yeni rekord oldu hətta avropada dünyada erkən çempionluq tituluna yiyələnən komandalar az olub buna uğur asanlıqla əldə edilmədi komanda bizdən xal almağa çalışır qarabağ avropada tarix yazdıqca azərbaycan çempionatında komandanın bizə motivasiyası artır bizi sevindirir yerli klubların bizə rəqabət yaratmağa çalışması qarabağ ı avropaya yaxşı hazırlayır çempionatın səviyyəsinin qalxmasına təkan verir düşünməsin premyer liqadakı rəqiblərimiz zəifdir əksinə onlar güclüdürlər amma onların qarşısında güclü avropa təcrübəsinə malik qarabağ uğurlar bizim qarabağ yaratdığımız birlik ruhunun nəticəsidir klubun rəhbərliyindən baş məşqçisindən sıravi işçisinə hamının böyük mənəvi birlik rekord sayda çempionluq münasibətilə başda məşqçilər heyəti olmaqla futbolçularımı klubumuzda çalışan kəsi ürəyi qarabağ la döyünən azarkeşlərimizi təbrik edirəm tahir gözəl növbəti hədəflərə toxunub əldə olunan nəticələr qarabağ dünya avropa reytinqlərində yüksəlməsinə əsas verib komandamız beynəlxalq futbol tarixi statistikaları federasiyasının dünya reytinqində yerdədir on minlərlə klub siyahida yer almaq mübarizə aparır çempionluq kubokunu doğma azersun arena aldıqdan sonra bizi kubok uğrunda final qarşılaşması gözləyir həmin oyunda iştirak edəcəyəm görüşü səbirsizliklə həyəcanla gözləyirəm zirə güclü komandadır rəşad sadıqov mükəmməl heyət formalaşdırıb amma biz titul qazanmağa mövsümü qızıl dubl la tamamlanmağa çalışacağıq ardınca isə yeni mövsümə böyük motivasiya böyük ümid inamla hazırlaşacağıq titulumuzu növbəti dəfə qorumaq avropada yeni tarixlər yazmaq mübarizə aparacağıq i̇llərdir qarabağ adını avropada qürurla daşıyırıq artıq müzəffər ali baş komandanımızın rəhbərliyi azərbaycan əsgərinin böyük zəfəri sayəsində azad qarabağı təmsil edirik qarabağ adının klubun azərbaycan mənəvi cəhətdən necə önəm daşıdığını anlayırıq bilirik qarabağ futbol klubu missiyamız bitmir bundan sonra qarabağın adını avropada layiqincə təmsil etməliyik mənim əsas klubumuzun illik uğuru deyil davamlı nəticələrdir komandamıza inamım sonsuzdur qol az
# sabah misli premyer liqasında mövsümünə yekun vurulacaq football plus az xəbər verir turun azersun arena keçiriləcək araz naxçıvan qarabağ oyunundan sonra köhlən atlar qızıl medallar çempionluq kuboku təqdim ediləcək ağdam təmsilçisinin prezidenti tahir gözel ölkə xaricində təşkil olunan vacib tədbirə qatıldığı mükafatlandırmada iştirak edə bilməyəcək o klubun mətbuat xidmətinə açıqlamasında komandanı azarkeşləri növbəti uğurlu mövsüm münasibətilə təbrik edib möhtəşəm mövsümə şahid olduq azərbaycan xalqı dünya avropada mükəmməl qarabağ izlədi ardıcıl dəfə avrokubokların qrupunda mübarizə aparan komandamız pley offda portuqaliyanın tanınmış braqa klubunu məğlub etdi avropada kimə uduzmayan bayer seriyasını qırmağa yaxın oldu almaniya təmsilçisinin baş məşqçisi futbolçuları komandamızla qarşılaşmaların çətin keçdiyini dəfələrlə vurğuladılar uğurların ardınca qarabağ premyer liqada ardıcıl tarixində çempionluğunu qazandı sabah komandamıza növbəti qızıl medallar təqdim olunacaq vacib təxirəsalınmaz işlərimlə bağlı komandamızın mükafatlandırma mərasimində iştirak edə bilməyəcəyəm amma ürəyim komandamızın yanında olacaq dəfə qızıl medalları sona tur qalmış təmin etdik yeni rekord oldu hətta avropada dünyada erkən çempionluq tituluna yiyələnən komandalar az olub buna uğur asanlıqla əldə edilmədi komanda bizdən xal almağa çalışır qarabağ avropada tarix yazdıqca azərbaycan çempionatında komandanın bizə motivasiyası artır bizi sevindirir yerli klubların bizə rəqabət yaratmağa çalışması qarabağ ı avropaya yaxşı hazırlayır çempionatın səviyyəsinin qalxmasına təkan verir düşünməsin premyer liqadakı rəqiblərimiz zəifdi əksinə onlar güclüdürlər amma onların qarşısında güclü avropa təcrübəsinə malik qarabağ uğurlar bizim qarabağ yaratdığımız birlik ruhunun nəticəsidi klubun rəhbərliyindən baş məşqçisindən sıravi işçisinə hamının böyük mənəvi birlik rekord sayda çempionluq münasibətilə başda məşqçilər heyəti olmaqla futbolçularımı klubumuzda çalışan kəsi ürəyi qarabağ la döyünən azarkeşlərimizi təbrik edirəm klub prezidenti növbəti hədəflərə toxunub əldə olunan nəticələr qarabağ dünya avropa reytinqlərində yüksəlməsinə əsas verib komandamız beynəlxalq futbol tarixi statistikaları federasiyasının dünya reytinqində yerdədi on minlərlə klub siyahida yer almaq mübarizə aparır çempionluq kubokunu doğma azersun arena aldıqdan sonra bizi kubok uğrunda final qarşılaşması gözləyir həmin oyunda iştirak edəcəyəm görüşü səbirsizliklə həyəcanla gözləyirəm zirə güclü komandadı rəşad sadıqov mükəmməl heyət formalaşdırıb amma biz titul qazanmağa mövsümü qızıl dubl la tamamlanmağa çalışacağıq ardınca isə yeni mövsümə böyük motivasiya böyük ümid inamla hazırlaşacağıq titulumuzu növbəti dəfə qorumaq avropada yeni tarixlər yazmaq mübarizə aparacağıq i̇llərdi qarabağ adını avropada qürurla daşıyırıq artıq müzəffər ali baş komandanımızın rəhbərliyi azərbaycan əsgərinin böyük zəfəri sayəsində azad qarabağı təmsil edirik qarabağ adının klubun azərbaycan mənəvi cəhətdən necə önəm daşıdığını anlayırıq bilirik qarabağ futbol klubu missiyamız bitmir bundan sonra qarabağın adını avropada layiqincə təmsil etməliyik mənim əsas klubumuzun illik uğuru deyil davamlı nəticələrdi komandamıza inamım sonsuzdu

# %% [markdown]
# # Similarity finder as a function

# %%
import numpy as np
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
def clean_text(text):
  text = re.sub(r'[\d.,!@#$%^&*:()"”“\-–=/]', ' ', text).lower()
  return text

def find_similarity(text1, text2):
    tfidf = TfidfVectorizer()
    text1 = clean_text(text1)
    text2 = clean_text(text2)
    tfidf_matrix = tfidf.fit_transform([text1, text2])
    similarity_score = cosine_similarity(tfidf_matrix[0], tfidf_matrix[1])[0][0]
    return similarity_score

# %% [markdown]
# Example

# %%
text1 = "sabah misli premyer liqasında mövsümünə yekun vurulacaq millətin səsi az xəbər verir turun azersun arena keçiriləcək araz naxçıvan qarabağ oyunundan sonra qarabağ qızıl medallar çempionluq kuboku təqdim ediləcək qarabağ yaydığı açıqlamada bildirilib klub prezidenti tahir gözel ölkə xaricində təşkil olunan vacib tədbirə qatıldığı mükafatlandırmada iştirak edə bilməyəcək o klubun mətbuat xidmətinə açıqlamasında komandanı azarkeşləri növbəti uğurlu mövsüm münasibətilə təbrik edib möhtəşəm mövsümə şahid olduq azərbaycan xalqı dünya avropada mükəmməl qarabağ izlədi ardıcıl dəfə avrokubokların qrupunda mübarizə aparan komandamız pley offda portuqaliyanın tanınmış braqa klubunu məğlub etdi avropada kimə uduzmayan bayer seriyasını qırmağa yaxın oldu almaniya təmsilçisinin baş məşqçisi futbolçuları komandamızla qarşılaşmaların çətin keçdiyini dəfələrlə vurğuladılar uğurların ardınca qarabağ premyer liqada ardıcıl tarixində çempionluğunu qazandı sabah komandamıza növbəti qızıl medallar təqdim olunacaq vacib təxirəsalınmaz işlərimlə bağlı komandamızın mükafatlandırma mərasimində iştirak edə bilməyəcəyəm amma ürəyim komandamızın yanında olacaq dəfə qızıl medalları sona tur qalmış təmin etdik yeni rekord oldu hətta avropada dünyada erkən çempionluq tituluna yiyələnən komandalar az olub buna uğur asanlıqla əldə edilmədi komanda bizdən xal almağa çalışır qarabağ avropada tarix yazdıqca azərbaycan çempionatında komandanın bizə motivasiyası artır bizi sevindirir yerli klubların bizə rəqabət yaratmağa çalışması qarabağ ı avropaya yaxşı hazırlayır çempionatın səviyyəsinin qalxmasına təkan verir düşünməsin premyer liqadakı rəqiblərimiz zəifdir əksinə onlar güclüdürlər amma onların qarşısında güclü avropa təcrübəsinə malik qarabağ uğurlar bizim qarabağ yaratdığımız birlik ruhunun nəticəsidir klubun rəhbərliyindən baş məşqçisindən sıravi işçisinə hamının böyük mənəvi birlik rekord sayda çempionluq münasibətilə başda məşqçilər heyəti olmaqla futbolçularımı klubumuzda çalışan kəsi ürəyi qarabağ la döyünən azarkeşlərimizi təbrik edirəm tahir gözəl növbəti hədəflərə toxunub əldə olunan nəticələr qarabağ dünya avropa reytinqlərində yüksəlməsinə əsas verib komandamız beynəlxalq futbol tarixi statistikaları federasiyasının dünya reytinqində yerdədir on minlərlə klub siyahida yer almaq mübarizə aparır çempionluq kubokunu doğma azersun arena aldıqdan sonra bizi kubok uğrunda final qarşılaşması gözləyir həmin oyunda iştirak edəcəyəm görüşü səbirsizliklə həyəcanla gözləyirəm zirə güclü komandadır rəşad sadıqov mükəmməl heyət formalaşdırıb amma biz titul qazanmağa mövsümü qızıl dubl la tamamlanmağa çalışacağıq ardınca isə yeni mövsümə böyük motivasiya böyük ümid inamla hazırlaşacağıq titulumuzu növbəti dəfə qorumaq avropada yeni tarixlər yazmaq mübarizə aparacağıq i̇llərdir qarabağ adını avropada qürurla daşıyırıq artıq müzəffər ali baş komandanımızın rəhbərliyi azərbaycan əsgərinin böyük zəfəri sayəsində azad qarabağı təmsil edirik qarabağ adının klubun azərbaycan mənəvi cəhətdən necə önəm daşıdığını anlayırıq bilirik qarabağ futbol klubu missiyamız bitmir bundan sonra qarabağın adını avropada layiqincə təmsil etməliyik mənim əsas klubumuzun illik uğuru deyil davamlı nəticələrdir komandamıza inamım sonsuzdur qol az"
text2 = "sabah misli premyer liqasında mövsümünə yekun vurulacaq football plus az xəbər verir turun azersun arena keçiriləcək araz naxçıvan qarabağ oyunundan sonra köhlən atlar qızıl medallar çempionluq kuboku təqdim ediləcək ağdam təmsilçisinin prezidenti tahir gözel ölkə xaricində təşkil olunan vacib tədbirə qatıldığı mükafatlandırmada iştirak edə bilməyəcək o klubun mətbuat xidmətinə açıqlamasında komandanı azarkeşləri növbəti uğurlu mövsüm münasibətilə təbrik edib möhtəşəm mövsümə şahid olduq azərbaycan xalqı dünya avropada mükəmməl qarabağ izlədi ardıcıl dəfə avrokubokların qrupunda mübarizə aparan komandamız pley offda portuqaliyanın tanınmış braqa klubunu məğlub etdi avropada kimə uduzmayan bayer seriyasını qırmağa yaxın oldu almaniya təmsilçisinin baş məşqçisi futbolçuları komandamızla qarşılaşmaların çətin keçdiyini dəfələrlə vurğuladılar uğurların ardınca qarabağ premyer liqada ardıcıl tarixində çempionluğunu qazandı sabah komandamıza növbəti qızıl medallar təqdim olunacaq vacib təxirəsalınmaz işlərimlə bağlı komandamızın mükafatlandırma mərasimində iştirak edə bilməyəcəyəm amma ürəyim komandamızın yanında olacaq dəfə qızıl medalları sona tur qalmış təmin etdik yeni rekord oldu hətta avropada dünyada erkən çempionluq tituluna yiyələnən komandalar az olub buna uğur asanlıqla əldə edilmədi komanda bizdən xal almağa çalışır qarabağ avropada tarix yazdıqca azərbaycan çempionatında komandanın bizə motivasiyası artır bizi sevindirir yerli klubların bizə rəqabət yaratmağa çalışması qarabağ ı avropaya yaxşı hazırlayır çempionatın səviyyəsinin qalxmasına təkan verir düşünməsin premyer liqadakı rəqiblərimiz zəifdi əksinə onlar güclüdürlər amma onların qarşısında güclü avropa təcrübəsinə malik qarabağ uğurlar bizim qarabağ yaratdığımız birlik ruhunun nəticəsidi klubun rəhbərliyindən baş məşqçisindən sıravi işçisinə hamının böyük mənəvi birlik rekord sayda çempionluq münasibətilə başda məşqçilər heyəti olmaqla futbolçularımı klubumuzda çalışan kəsi ürəyi qarabağ la döyünən azarkeşlərimizi təbrik edirəm klub prezidenti növbəti hədəflərə toxunub əldə olunan nəticələr qarabağ dünya avropa reytinqlərində yüksəlməsinə əsas verib komandamız beynəlxalq futbol tarixi statistikaları federasiyasının dünya reytinqində yerdədi on minlərlə klub siyahida yer almaq mübarizə aparır çempionluq kubokunu doğma azersun arena aldıqdan sonra bizi kubok uğrunda final qarşılaşması gözləyir həmin oyunda iştirak edəcəyəm görüşü səbirsizliklə həyəcanla gözləyirəm zirə güclü komandadı rəşad sadıqov mükəmməl heyət formalaşdırıb amma biz titul qazanmağa mövsümü qızıl dubl la tamamlanmağa çalışacağıq ardınca isə yeni mövsümə böyük motivasiya böyük ümid inamla hazırlaşacağıq titulumuzu növbəti dəfə qorumaq avropada yeni tarixlər yazmaq mübarizə aparacağıq i̇llərdi qarabağ adını avropada qürurla daşıyırıq artıq müzəffər ali baş komandanımızın rəhbərliyi azərbaycan əsgərinin böyük zəfəri sayəsində azad qarabağı təmsil edirik qarabağ adının klubun azərbaycan mənəvi cəhətdən necə önəm daşıdığını anlayırıq bilirik qarabağ futbol klubu missiyamız bitmir bundan sonra qarabağın adını avropada layiqincə təmsil etməliyik mənim əsas klubumuzun illik uğuru deyil davamlı nəticələrdi komandamıza inamım sonsuzdu"
similarity = find_similarity(text1, text2)
print(f"Cosine Similarity between text1 and text2: {similarity:.2f}")
# Out:
# Cosine Similarity between text1 and text2: 0.96
